# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### - Ejercicio 1

# %% [markdown]
# Parte el conjunto de datos adjunto en train y test. Estudia ambos conjuntos por separado, a nivel descriptivo.
#
# También adjunto encontrarás una descripción de las diferentes variables del dataset.

# %%
archivo = open(r"C:\Users\dpino\Documents\DATA SCIENCE\Jupyter\BOOTCAMP\T5.2\housing data description.txt")
print(archivo.read())
# Out:
# 1. Title: Boston Housing Data
#
# 2. Sources:
#    (a) Origin:  This dataset was taken from the StatLib library which is
#                 maintained at Carnegie Mellon University.
#    (b) Creator:  Harrison, D. and Rubinfeld, D.L. 'Hedonic prices and the
#                  demand for clean air', J. Environ. Economics & Management,
#                  vol.5, 81-102, 1978.
#    (c) Date: July 7, 1993
#
# 3. Past Usage:
#    -   Used in Belsley, Kuh & Welsch, 'Regression diagnostics ...', Wiley,
#        1980.   N.B. Various transformations are used in the table on
#        pages 244-261.
#     -  Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning.
#        In Proceedings on the Tenth International Conference of Machine
#        Learning, 236-243, University of Massachusetts, Amherst. Morgan
#        Kaufmann.
#
# 4. Relevant Information:
#
#    Concerns housing values in suburbs of Boston.
#
# 5. Number of Instances: 506
#
# ...

# %% [markdown]
# En esta descripcion de variables, ( Datos de vivienda de Boston ).
#
# Informacion relevante:el conjunto de datos hace  referencia al Valor de la vivienda en los suburbios de Boston.
# Intancias (filas): 506: Zonas Evaluadas
#
# Atributos (Columnas): 13 + 1 un abributo de valor binario.
#
# Informacion Atributos: describe los 13 atributos:
#
# 1. CRIM: tasa de criminalidad per capita por ciudad.
# 2. ZN: para lotes de más de 25,000 pies cuadrados.proporción de su suelo residencial zonificado.
# 3. INDUS: proporción de acres para la industria por ciudad
# 4. CHAS: Variable ficticia Charles River. (= 1 si los límites del tramo río; 0 en caso contrario)
# 5. NOX: Concentración de óxidos nítricos (partes por 10 millones)
# 6. RM: Numero media de habitaciones por vivienda.
# 7. AGE: proporción de unidades de vivienda que estan ocupadas por sus propietarios y que fueron contruidas antes de 1940.
# 8. DIS: distancias ponderadas a cinco centros de empleo de Boston
# 9. RAD: índice de accesibilidad a carreteras radiales
# 10. TAX: tasa de impuesto a la propiedad de valor total por $10,000
# 11. PTRATIO: proporcion de estudiantes por docentes, por localidad
# 12. B: 1000(Bk - 0,63)^2 donde Bk es la proporción de negros por ciudad
# 13. LSTAT: % de poblacion con estatus más bajo.
# 14. MEDV: Valor medio de viviendas ocupadas por sus propietarios en miles de dólares.
#
# Ademas nos informa que no faltan datos en este conjunti de datos.

# %%
df = pd.read_csv(r"C:\Users\dpino\Documents\DATA SCIENCE\Jupyter\BOOTCAMP\T5.2\housing data.csv", sep=",", header=None, engine="python", encoding="latin-1")

# %%
df.columns = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]
df.head(50)
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311.0
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311.0
# ...

# %%
df.CHAS.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.ZN.unique()
# Out:
# array([ 18. ,   0. ,  12.5,  75. ,  21. ,  90. ,  85. , 100. ,  25. ,
#         17.5,  80. ,  28. ,  45. ,  60. ,  95. ,  82.5,  30. ,  22. ,
#         20. ,  40. ,  55. ,  52.5,  70. ,  34. ,  33. ,  35. ])

# %%
df.RAD.unique()
# Out:
# array([ 1,  2,  3,  5,  4,  8,  6,  7, 24], dtype=int64)

# %%
df.DIS.nunique()
# Out:
# 412

# %%
df.shape
# Out:
# (506, 14)

# %%
df.describe().round(3)
# Out:
#           CRIM       ZN    INDUS     CHAS      NOX       RM      AGE      DIS  \
# count  506.000  506.000  506.000  506.000  506.000  506.000  506.000  506.000
# mean     3.614   11.364   11.137    0.069    0.555    6.285   68.575    3.795
# std      8.602   23.322    6.860    0.254    0.116    0.703   28.149    2.106
# min      0.006    0.000    0.460    0.000    0.385    3.561    2.900    1.130
# 25%      0.082    0.000    5.190    0.000    0.449    5.885   45.025    2.100
# 50%      0.257    0.000    9.690    0.000    0.538    6.208   77.500    3.207
# 75%      3.677   12.500   18.100    0.000    0.624    6.624   94.075    5.188
# max     88.976  100.000   27.740    1.000    0.871    8.780  100.000   12.126
#
#            RAD      TAX  PTRATIO        B    LSTAT     MEDV
# count  506.000  506.000  506.000  506.000  506.000  506.000
# mean     9.549  408.237   18.456  356.674   12.653   22.533
# std      8.707  168.537    2.165   91.295    7.141    9.197
# ...

# %% [markdown]
# Analisis estadistico:
#
# CRIM: La media de crimininalidad Per Capital es de 3.614, teniendo un min de 0.006 y un max 88.976 ( muy alto)
#
# ZN: Los lotes de mas de 25.000 pies cuadrados tiene una media de ocupacion residencial de 11.367%. el min (lotes que no son de mas de 25.000 pies cuadrados) y max 100%
#
# INDUS: tiene una media de 11.137 dedicados a la industria. con un min de 0.460 y un max de 27.740.
#
# NOX. concrentracion de acido nitrico tiene una media de 0.555, con un min por zona de 0.385 y un max de 0.871.
#
# RM: de la media de habitaciones por vivienda de todas las zonas de los suburbios de Boston es de 6.285.
#
# AGE: tiene una media de 68.575 propietarios que construyeron sus casa antes de 1940 y aun viven allì. min 2.9% y max de 100%.
#
# DIS: La media de distancias a centros de empleo tiene una media de 3.795. un min de 1130 y un max de 12.126.
#
# TAX: Impuesto a la propiedad, tiene un promedio de 408.237$. min de 187.000$ y un max de 711.000$.
#
# PTRATIO: Hay una media de estudiantes por profesor de 18.45. un min de 12.6 y un max de 22.00.
#
# B: La media de proporción de negros por ciudad es de 356.674. un min de 0.320 y un max de 396.900.
#
# LSTAT: media de 12.653% de poblacion en un estatus bajo en todos los suburbios de Boston, con un porcentaje min de 1.73% y un max de 37.97%.
#
# MEDV: El valor medio de las viviendas ocupadas por sus propietarios es de 22.533$. min de 5.000$ y un max de 50.000$.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# El conjunto de datos no tiene datos nulos o faltantes y el tipo de dato para los atributos es float, excepto para el atributo CHAS Y RAD, esto puede deberse a que es una variabel categorica. mientras que las demas variables son numericas.

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(16, 10))
for i, column in enumerate(df.columns):
    plt.subplot(4, 4, i+1)
    sns.histplot(df[column], kde=True)
    plt.title(column)
    plt.tight_layout()
plt.show()

# %% [markdown]
# En estos Histogramas podemos ver el reflejo del ocnjunto de datos:
#
# CRIM: Los datos se concentran en el primer rango y los demas se van repartiendo a lo largo de los rangos, significa que la criminalidad es baja en la mayoria de zonas, pero existen datos de zonas con criminalidad alta en rangos altos, lo que podria significar una anormalidad en los datos, el histograma no hace forma de campana.
#
# ZN: la media de ocupacion residencial en lotes de mas de 25.000 pies cuadrados tiene, muestra que la mayoria se concentran en un rango de 0 - 10%, sin enbargo tambien hay datos en otros rangos, incluso hay una ocupación residencial del 100%. pero con menos cantidad de zonas, la concentracion en un solo rango de los datso podria significar anormalidad en los datos, el histograma no hace campana.
#
# INDUS: vemos mas variedad de datos, a lo largo de los rangos pero varian rango a rango de forma extrema, hay rangos donde se concentran los datos y otros donde hay muy pocos datos. podria significar que hay datos extremos, el histograma no hace forma de camapana.
#
# CHAS: Al ser una variable caterogica, muestra que los datos se concentran en dos puntos el o y el 1.
#
# NOX: La concentracio nde acido nitrico, se reparte a lo largo de los rangos, se ve que las concentraciones con mayores rangos, esta en los rangos mas bajos. pero existe una concentracion pequeña en el rango mas alto. los datos varian con una tnedencia a la baja, sin embargo en el ultimo rango aumenta, por tanto podria ser una anormalidad de los datos, el histograma no hace camapana.
#
# RM: Habitaciones por vivienda, se ve que hay una concentracio nde los datos en el rango 6, y aumenta o disminuye la cantidad a lado y lado de este. los datos se distribuyen de mejor forma que otras variables y el histograma hace forma de campana. podria significar una normalidad en los datos.
#
# AGE: La media de propietarios que construyeron sus casa antes de 1940 y aun viven allì. es baja en los primeros rangos y alta en los ultimos, lo cual significaria que mas propietarios son los que aun viven en la vivienda que construyeron antes de 1940 que los que ya no viven en esas viviendad. hay concentracion de datos en un rango y los demas van desendiendo hacia un solo lado de este rango que ocncentra la mayoria de datos, podria ser significar anomralidad, el histograma no muestra una campana.
#
# DIS: La media de distancias a centros de empleo muestra una concentracin de datos en el primer rango y un desenso prolongado a lo largo de los demas rangos, los datos desienden sostenidamente, podrian los datso no ser normales y el histograma no hace campana.
#
# RAD: El índice de accesibilidad a carreteras radiales es una variable categorica, vemos que los datos se concentran en una variable, y hay un datos extremos. no hace campana.
#
# TAX: Impuesto a la propiedad, Los datos se distribuyen en los primeros rangos, con variaciones den rango a rango, hay datos extremos y cierta concentracion de estos en el ultimo rango, muchas zonas tiene un impuesto costoso. el histograma no hace campana.
#
# PTRATIO: Hay una media de estudiantes por profesor, la media es alta en la mayoria de zonas, sin embargo existen zonas con medias muy bajas de estudiantes por profesor, los datos se distribuyen, pero la mayoria se concentra en un rango, hay datos extremos y no hace camapana.
#
# B: La media de proporción de negros por ciudad, existe concentracion de datos en un solo rango, significaria que existe la misma cantidad de negros en la mayoria de ciudades, pero rango extremos, o sea que hya rangos muy bajos o poblacion de negros baja en algunas ciudades. esta concentracion de datos en un solo rango significaria anomralidad de los datos y hay datos extremos.
#
# LSTAT: % de poblacion con estatus más bajo, la mayoria de zonas tiene porcentajes de poblacion en estatus bajo del 0 al 20% es odnde se concentrna los datos, sin embargo hay poblaciones donde el estatus bajo es alto. esto podria significar anormalidad de datos y que existen datos extremos.
#
# MEDV: El valor medio de las viviendas ocupadas por sus propietarios, vemos una distribucion semejante a la normal, los datos descienden de lado y lado de forma constantes, puede significar normalidad de los datos, el histograma hace campana.

# %%
sns.histplot(df['MEDV'], bins=10, kde=True)
plt.suptitle("Histograma de Promedio de Precios de Casas de Boston", size= 14)
plt.xlabel("Precio promedio de las casas (en miles de dolares)")
plt.show()

# %% [markdown]
# Vemos en un rango de precios en el eje x: del 0 al 50 representado en miles que la mayoria de viviendas ocupadas por el propietario y la cantidad de viviendas representadas en el eje y, que la mayoria de viviendas, al rededor de 155 viviendas tienen un valor que oscila en los 20 mil, siendo el mas costoso, luego 80 viviendas tienen un valor de aproximadamente 16 mil y 25 mil, la menor cantidad de viviendas al rededor de 10, tiene un valor aproximado de 39 mil.

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop("MEDV",axis=1)
y=df.MEDV
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33 )

# %%
X_train.shape
# Out:
# (339, 13)

# %%
X_test.shape
# Out:
# (167, 13)

# %%
y_train.shape
# Out:
# (339,)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS  RAD    TAX  \
# 357   3.84970   0.0  18.10     1  0.7700  6.395   91.0  2.5052   24  666.0
# 58    0.15445  25.0   5.13     0  0.4530  6.145   29.2  7.8148    8  284.0
# 418  73.53410   0.0  18.10     0  0.6790  5.957  100.0  1.8026   24  666.0
# 105   0.13262   0.0   8.56     0  0.5200  5.851   96.7  2.1069    5  384.0
# 487   4.83567   0.0  18.10     0  0.5830  5.905   53.2  3.1523   24  666.0
# ..        ...   ...    ...   ...     ...    ...    ...     ...  ...    ...
# 421   7.02259   0.0  18.10     0  0.7180  6.006   95.3  1.8746   24  666.0
# 215   0.19802   0.0  10.59     0  0.4890  6.182   42.4  3.9454    4  277.0
# 298   0.06466  70.0   2.24     0  0.4000  6.345   20.1  7.8278    5  358.0
# 305   0.05479  33.0   2.18     0  0.4720  6.616   58.1  3.3700    7  222.0
# 331   0.05023  35.0   6.06     0  0.4379  5.706   28.4  6.6407    1  304.0
#
#      PTRATIO       B  LSTAT
# 357     20.2  391.34  13.27
# ...

# %%
y_train
# Out:
# 357    21.7
# 58     23.3
# 418     8.8
# 105    19.5
# 487    20.6
#        ...
# 421    14.2
# 215    25.0
# 298    22.5
# 305    28.4
# 331    17.1
# Name: MEDV, Length: 339, dtype: float64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 339 entries, 357 to 331
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     339 non-null    float64
#  1   ZN       339 non-null    float64
#  2   INDUS    339 non-null    float64
#  3   CHAS     339 non-null    int64
#  4   NOX      339 non-null    float64
#  5   RM       339 non-null    float64
#  6   AGE      339 non-null    float64
#  7   DIS      339 non-null    float64
#  8   RAD      339 non-null    int64
#  9   TAX      339 non-null    float64
#  10  PTRATIO  339 non-null    float64
#  11  B        339 non-null    float64
#  12  LSTAT    339 non-null    float64
# dtypes: float64(11), int64(2)
# memory usage: 37.1 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 339 entries, 357 to 331
# Series name: MEDV
# Non-Null Count  Dtype
# --------------  -----
# 339 non-null    float64
# dtypes: float64(1)
# memory usage: 5.3 KB

# %% [markdown]
# el conjunto de datos que resulta de partir en train y test son 4 subconjuntos. (2 para train X y y)
#
# Para Train: X_train y y_train.
#
# Estos datos aleatorios resultado de la aplicación de train_test_split. corresponden a test 0.67% del conjunto de datos de todo el conjunto original, subdividido para train en (X_train y y_train ).
#
# X_train= corresponde al 0.67%  las variables independientes ( 12 columnas con diferentes datos ).
#
# y_train= corresponde al 0,67% del atributo dependiente MEDV que es el objeto de estudio
#
# El tipo de dato para X_train, son en su mayoria float pero existen dos atributos con tipo de dato int ( contiene una variable categorica ) , mientras que y_train tiene un tipo de dato float.

# %%
y_test.shape
# Out:
# (167,)

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 139  0.54452   0.0  21.89     0  0.624  6.151   97.9  1.6687    4  437.0
# 258  0.66351  20.0   3.97     0  0.647  7.333  100.0  1.8946    5  264.0
# 390  6.96215   0.0  18.10     0  0.700  5.713   97.0  1.9265   24  666.0
# 290  0.03502  80.0   4.95     0  0.411  6.861   27.9  5.1167    4  245.0
# 166  2.01019   0.0  19.58     0  0.605  7.929   96.2  2.0459    5  403.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 389  8.15174   0.0  18.10     0  0.700  5.390   98.9  1.7281   24  666.0
# 393  8.64476   0.0  18.10     0  0.693  6.193   92.6  1.7912   24  666.0
# 148  2.33099   0.0  19.58     0  0.871  5.186   93.8  1.5296    5  403.0
# 94   0.04294  28.0  15.04     0  0.464  6.249   77.3  3.6150    4  270.0
# 88   0.05660   0.0   3.41     0  0.489  7.007   86.3  3.4217    2  270.0
#
#      PTRATIO       B  LSTAT
# 139     21.2  396.90  18.46
# 258     13.0  383.29   7.79
# ...

# %%
y_test
# Out:
# 139    17.8
# 258    36.0
# 390    15.1
# 290    28.5
# 166    50.0
#        ...
# 389    11.5
# 393    13.8
# 148    17.8
# 94     20.6
# 88     23.6
# Name: MEDV, Length: 167, dtype: float64

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167 entries, 139 to 88
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     167 non-null    float64
#  1   ZN       167 non-null    float64
#  2   INDUS    167 non-null    float64
#  3   CHAS     167 non-null    int64
#  4   NOX      167 non-null    float64
#  5   RM       167 non-null    float64
#  6   AGE      167 non-null    float64
#  7   DIS      167 non-null    float64
#  8   RAD      167 non-null    int64
#  9   TAX      167 non-null    float64
#  10  PTRATIO  167 non-null    float64
#  11  B        167 non-null    float64
#  12  LSTAT    167 non-null    float64
# dtypes: float64(11), int64(2)
# memory usage: 18.3 KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 167 entries, 139 to 88
# Series name: MEDV
# Non-Null Count  Dtype
# --------------  -----
# 167 non-null    float64
# dtypes: float64(1)
# memory usage: 2.6 KB

# %% [markdown]
# el conjunto de datos que resulta con la aplicacion de train y test a X y y son 4 subconjuntos.
#
# Para Test: X_test y y_test.
#
# Estos datos aleatorios resultado de la aplicación de train_test_split. para X (variables independientes) y para y ( variable dependiente, resultado)
#
# X_test= corresponde al 0.33%  las variables independientes ( 12 columnas con diferentes datos ).
#
# y_test= corresponde al 0,33% del atributo dependiente MEDV que es el objeto de estudio.
#
# El tipo de dato para X_test y y_test, son en su mayoria float pero existen dos atributos con tipo de dato int ( contiene una clasificación ) , mientras que y_test y tiene un tipo de dato float.

# %%
X_train.describe().round(3)
# Out:
#           CRIM       ZN    INDUS     CHAS      NOX       RM      AGE      DIS  \
# count  339.000  339.000  339.000  339.000  339.000  339.000  339.000  339.000
# mean     3.910   10.900   11.136    0.065    0.558    6.250   70.283    3.801
# std      9.177   22.333    6.681    0.247    0.115    0.655   27.540    2.142
# min      0.014    0.000    0.460    0.000    0.385    4.368    2.900    1.130
# 25%      0.089    0.000    5.190    0.000    0.458    5.875   47.500    2.075
# 50%      0.299    0.000    9.690    0.000    0.538    6.163   79.900    3.216
# 75%      3.686   12.500   18.100    0.000    0.631    6.554   94.450    5.230
# max     88.976  100.000   27.740    1.000    0.871    8.704  100.000   12.126
#
#            RAD      TAX  PTRATIO        B    LSTAT
# count  339.000  339.000  339.000  339.000  339.000
# mean     9.622  408.454   18.439  355.769   13.125
# std      8.696  165.609    2.280   92.955    7.182
# min      1.000  187.000   12.600    2.600    1.730
# ...

# %%
X_train_describe = X_train.describe().round(3)
X_train_describe_transposed = X_train_describe.T
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 10))
for i, column in enumerate(X_train_describe_transposed.columns):
    ax = axes[i // 4, i % 4]
    X_train_describe_transposed[column].plot(kind='bar', color='skyblue', ax=ax)
    ax.set_title(f'Distribución de {column}')
    ax.set_xlabel('Columnas')
    ax.set_ylabel('Valor')
plt.tight_layout()
plt.show()

# %%
X_test.describe().round(3)
# Out:
#           CRIM       ZN    INDUS     CHAS      NOX       RM      AGE      DIS  \
# count  167.000  167.000  167.000  167.000  167.000  167.000  167.000  167.000
# mean     3.012   12.305   11.139    0.078    0.548    6.356   65.107    3.784
# std      7.283   25.256    7.231    0.269    0.118    0.787   29.122    2.036
# min      0.006    0.000    0.740    0.000    0.389    3.561    6.000    1.137
# 25%      0.069    0.000    4.950    0.000    0.447    5.959   37.100    2.151
# 50%      0.183    0.000    9.900    0.000    0.515    6.273   70.400    3.199
# 75%      3.398   15.250   18.100    0.000    0.619    6.710   93.150    5.109
# max     73.534   95.000   27.740    1.000    0.871    8.780  100.000   10.710
#
#            RAD      TAX  PTRATIO        B    LSTAT
# count  167.000  167.000  167.000  167.000  167.000
# mean     9.401  407.796   18.489  358.511   11.696
# std      8.754  174.837    1.916   88.073    6.980
# min      1.000  188.000   13.000    0.320    1.980
# ...

# %%
X_test_describe = X_test.describe().round(3)
X_test_describe_transposed = X_test_describe.T
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 10))
for i, column in enumerate(X_test_describe_transposed.columns):
    ax = axes[i // 4, i % 4]
    X_test_describe_transposed[column].plot(kind='bar', color='skyblue', ax=ax)
    ax.set_title(f'Distribución de {column}')
    ax.set_xlabel('Columnas')
    ax.set_ylabel('Valor')
plt.tight_layout()
plt.show()

# %% [markdown]
# Los conjuntos X_train y X_test:
#
# Extension: X_train: 339, X_test: 167.
#
# Mean: el promedio de los dos conjuntos es similar a pesar de que sin muy diferentes es extension.
#
# Std: son similares en sus rangos de desviacion estandar.
#
# min: son similares en los rangos sin embargo INDUS, AGE y B, tienen diferencias mas significativas.
#
# Max: son similares excepto por las variables CRIM, DIS y LSTAT.
#
# Graficamente tambien podemos confirmar que los dos conjuntos son similares en cuanto a promedio, desviacion estandar, minimos yt maximos, asi su cantidad sea diferente, la distribucion de los datos es similar.

# %% [markdown]
# ###  Ejercicio 2

# %% [markdown]
# Aplica algún proceso de transformación (estandarizar los datos numéricos, crear columnas dummies, polinomios...).

# %%
from sklearn.preprocessing import RobustScaler #No normales con outlier
from sklearn.preprocessing import StandardScaler #Normales
from sklearn.preprocessing import MinMaxScaler #No normales sin outlier

# %%
X_train_2= X_train.copy()
X_test_2= X_test.copy()

# %% [markdown]
# #### Aplicación de Prueba de Hipotesis Estadistica

# %%
from scipy.stats import shapiro
for x in X_train_2.columns.values:
    stat, p = shapiro(X_train_2[x])
    print('stat=%.3f, p=%.3f' % (stat, p))
    if p > 0.05:
        print('Probably Gaussian')
    else:
        print('Probably not Gaussian')
# Out:
# stat=0.427, p=0.000
# Probably not Gaussian
# stat=0.560, p=0.000
# Probably not Gaussian
# stat=0.905, p=0.000
# Probably not Gaussian
# stat=0.264, p=0.000
# Probably not Gaussian
# stat=0.946, p=0.000
# Probably not Gaussian
# stat=0.958, p=0.000
# Probably not Gaussian
# stat=0.887, p=0.000
# Probably not Gaussian
# stat=0.899, p=0.000
# Probably not Gaussian
# stat=0.686, p=0.000
# Probably not Gaussian
# stat=0.814, p=0.000
# Probably not Gaussian
# stat=0.901, p=0.000
# Probably not Gaussian
# stat=0.479, p=0.000
# Probably not Gaussian
# stat=0.937, p=0.000
# Probably not Gaussian

# %%
X_train_2.columns.values[0]
# Out:
# 'CRIM'

# %%
for x in X_test_2.columns.values:
    stat, p = shapiro(X_test_2[x])
    print('stat=%.3f, p=%.3f' % (stat, p))
    if p > 0.05:
        print('Probably Gaussian')
    else:
        print('Probably not Gaussian')
# Out:
# stat=0.565, p=0.000
# Probably not Gaussian
# stat=0.547, p=0.000
# Probably not Gaussian
# stat=0.887, p=0.000
# Probably not Gaussian
# stat=0.295, p=0.000
# Probably not Gaussian
# stat=0.910, p=0.000
# Probably not Gaussian
# stat=0.963, p=0.000
# Probably not Gaussian
# stat=0.901, p=0.000
# Probably not Gaussian
# stat=0.912, p=0.000
# Probably not Gaussian
# stat=0.665, p=0.000
# Probably not Gaussian
# stat=0.817, p=0.000
# Probably not Gaussian
# stat=0.907, p=0.000
# Probably not Gaussian
# stat=0.472, p=0.000
# Probably not Gaussian
# stat=0.932, p=0.000
# Probably not Gaussian

# %% [markdown]
# Hacemos la normalizaciòn de datos, con el metodo shapiro para cada atributo del ocnjunto de datos para saber si son normales o no.
# el resultado es que no son normales.

# %% [markdown]
# #### EDA PARA X_TRAIN

# %%
columns= X_train_2.columns
for i in columns:
    plt.figure(figsize=(3, 1))
    sns.set()
    sns.boxplot(x=X_train_2[i])
    plt.title(f'Boxplot para {i}')
    plt.show()

# %% [markdown]
# Con estos Boxplot podemos identificar los atributos que tienen datos extremos o llamados outliers ("CRIM", "ZN", "DIS", "RM","PTRATIO", "B", "LSTAT") en Train, que son datos que se encuentran fuera del rango de la mediana. donde se encuentra el 50 % de todos los datos.

# %%
sns.histplot(X_train_2['PTRATIO'], bins=10, kde=True)
plt.suptitle("Histograma de PTRATIO", size= 14)
plt.xlabel("PORCION DE ESTUDIANTES POR DOCENTES")
plt.show()

# %% [markdown]
# Respecto a la recorreccion grafico columna "PTRARIO" para identificar por que en X_train este variable tenia ouliers y en X_test no tenia ouliers, la razon tiene que ver con correr python, he vuelto a correrlo y efectivamente ambas tiene ouliers.

# %% [markdown]
# #### Tranformaciones numericas para Train
#
# Los datos no son normales como lo muestra el p_value, asi que separamos outlier y no outliers. Segun nos muestran los boxplot, que nos muestra los atributos que tienen o no outliers. y los tranformamos con diferentes metodos.
#
# Existen dos variables categoricas "CHAS" Y "RAD", por tanto se debe hacer otro tipo de transformacion.

# %%
columnas_escalarr=["CRIM", "ZN", "DIS", "RM","PTRATIO", "B", "LSTAT"]
scaler = RobustScaler()
X_train_2[columnas_escalarr] = scaler.fit_transform(X_train_2[columnas_escalarr])

# %% [markdown]
# Para el caso de los outliers usamos la tecnica RobustScaler, que nos tranforma los numeros de las columnas ("CRIM", "ZN", "DIS", "RM","PTRATIO", "B", "LSTAT") para el X_train_2.

# %%
columnas_escalarmm=["INDUS", "AGE", "NOX", "TAX"]
scaler = MinMaxScaler()
X_train_2[columnas_escalarmm] = scaler.fit_transform(X_train_2[columnas_escalarmm])

# %% [markdown]
# Para el caso de los No outliers usamos la tecnica MinMaxScaler, que nos tranforma los numeros de las columnas ("INDUS", "AGE", "NOX", "TAX") para el X_train_2.

# %%
X_train_2
# Out:
#           CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 357   0.992627  0.00  0.646628     1  0.792181  0.274457  0.907312 -0.213956
# 58   -0.030221  2.00  0.171188     0  0.139918 -0.065217  0.270855  1.422965
# 418  20.281332  0.00  0.646628     0  0.604938 -0.320652  1.000000 -0.430564
# 105  -0.036264  0.00  0.296921     0  0.277778 -0.464674  0.966014 -0.336750
# 487   1.265545  0.00  0.646628     0  0.407407 -0.391304  0.518023 -0.014459
# ..         ...   ...       ...   ...       ...       ...       ...       ...
# 421   1.870886  0.00  0.646628     0  0.685185 -0.254076  0.951596 -0.408367
# 215  -0.018161  0.00  0.371334     0  0.213992 -0.014946  0.406797  0.230049
# 298  -0.055075  5.60  0.065249     0  0.030864  0.206522  0.177137  1.426973
# 305  -0.057807  2.64  0.063050     0  0.179012  0.574728  0.568486  0.052657
# 331  -0.059069  2.80  0.205279     0  0.108848 -0.661685  0.262616  1.060996
#
# ...

# %% [markdown]
# Observamos que todas las columnas fueron tranformadas para X_Train_2, clasificando las que tenian o no, outliers, y transformandolas con diferentes tecnicas.

# %% [markdown]
# #### EDA PARA TEST

# %%
columns= X_test_2.columns
for i in columns:
    plt.figure(figsize=(3, 1))
    sns.set()
    sns.boxplot(x=X_test_2[i])
    plt.title(f'Boxplot para {i}')
    plt.show()

# %% [markdown]
# Con estos Boxplot podemos identificar los atributos que tienen datos extremos o llamados outliers ("CRIM", "ZN", "RM", "DIS", "PTRATIO", "B", "LSTAT") en Test, que son datos que se encuentran fuera del rango de la mediana. donde se encuentra el 50 % de todos los datos.

# %%
sns.histplot(X_test_2['PTRATIO'], bins=10, kde=True)
plt.suptitle("Histograma de PTRATIO", size= 14)
plt.xlabel("PORCION DE ESTUDIANTES POR DOCENTES")
plt.show()

# %% [markdown]
# #### Tranformaciones numericas para Test
#
# Los datos no son normales como lo muestra el p_value, asi que separamos outlier y no outliers. esto lo hacemos con boxplot, que nos muestra los atributos que tienen o no outliers.

# %%
columnas_escalarr=["CRIM", "ZN", "RM", "DIS", "PTRATIO", "B", "LSTAT"]
scaler = RobustScaler()
X_test_2[columnas_escalarr] = scaler.fit_transform(X_test_2[columnas_escalarr])

# %% [markdown]
# Para el caso de los outliers usamos la tecnica RobustScaler, que nos tranforma los numeros de las columnas ("CRIM", "ZN", "RM", "DIS", "B", "LSTAT") para el X_test_2.

# %%
columnas_escalarmm=["INDUS", "AGE", "NOX", "TAX"]
scaler = MinMaxScaler()
X_test_2[columnas_escalarmm] = scaler.fit_transform(X_test_2[columnas_escalarmm])

# %% [markdown]
# Para el caso de los No outliers usamos la tecnica MinMaxScaler, que nos tranforma los numeros de las columnas ("INDUS", "AGE", "NOX", "TAX", "PTRATIO") para el X_test_2.

# %%
X_test_2
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 139  0.117975  0.00  0.779412     0  0.477801 -0.087393  0.977540 -0.531349
# 258  0.162433  1.60  0.103695     0  0.526427  1.606017  1.000000 -0.456489
# 390  2.515754  0.00  0.636501     0  0.638478 -0.714900  0.967914 -0.445917
# 290 -0.072386  6.40  0.140649     0  0.027484  0.929799  0.228877  0.611280
# 166  0.665584  0.00  0.692308     0  0.437632  2.459885  0.959358 -0.406349
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 389  2.960213  0.00  0.636501     0  0.638478 -1.177650  0.988235 -0.511665
# 393  3.144417  0.00  0.636501     0  0.623679 -0.027221  0.920856 -0.490754
# 148  0.785443  0.00  0.692308     0  1.000000 -1.469914  0.933690 -0.577446
# 94  -0.069427  2.24  0.521116     0  0.139535  0.053009  0.757219  0.113633
# 88  -0.064323  0.00  0.082579     0  0.192389  1.138968  0.853476  0.049576
#
#      RAD       TAX   PTRATIO         B     LSTAT
# ...

# %% [markdown]
# Observamos que todas las columnas fueron tranformadas para X_test_2, clasificando las que tenian o no, outliers, y transformandolas con diferentes tecnicas

# %%
X_train_2.CHAS.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
X_train_2.RAD.unique()
# Out:
# array([24,  8,  5,  6,  7,  4,  3,  2,  1], dtype=int64)

# %% [markdown]
# Es importante identificar el tipo de variable o atributo que se tienen en el conjunto de datos, en este caso teniamos particularmente dos atributos de tipo categorico, por lo cual debemos procesar sus datos de diferente forma, el tipo de variable debe identificarse desde el principio para tener claro como procesar los datos.
# para este caso tenemos dos variables categoricas ( CHAS Y RAD ), por lo cual no podemos estandarizar numericamente estos dos atributos:
#
# Para la columna CHAS, aunque es categorica tambien en binaria por lo cual, no nos interesa transformarla.
#
# Para columna RAD, existe mas de un valor, por lo cual se crean Dummys de la siguiente forma:

# %%
dum_train = pd.get_dummies(X_train_2.RAD, prefix="RAD_", drop_first=True)
dum_train
# Out:
#      RAD__2  RAD__3  RAD__4  RAD__5  RAD__6  RAD__7  RAD__8  RAD__24
# 357       0       0       0       0       0       0       0        1
# 58        0       0       0       0       0       0       1        0
# 418       0       0       0       0       0       0       0        1
# 105       0       0       0       1       0       0       0        0
# 487       0       0       0       0       0       0       0        1
# ..      ...     ...     ...     ...     ...     ...     ...      ...
# 421       0       0       0       0       0       0       0        1
# 215       0       0       1       0       0       0       0        0
# 298       0       0       0       1       0       0       0        0
# 305       0       0       0       0       0       1       0        0
# 331       0       0       0       0       0       0       0        0
#
# [339 rows x 8 columns]

# %%
dum_test = pd.get_dummies(X_test_2.RAD, prefix="RAD_", drop_first=True)
dum_test
# Out:
#      RAD__2  RAD__3  RAD__4  RAD__5  RAD__6  RAD__7  RAD__8  RAD__24
# 139       0       0       1       0       0       0       0        0
# 258       0       0       0       1       0       0       0        0
# 390       0       0       0       0       0       0       0        1
# 290       0       0       1       0       0       0       0        0
# 166       0       0       0       1       0       0       0        0
# ..      ...     ...     ...     ...     ...     ...     ...      ...
# 389       0       0       0       0       0       0       0        1
# 393       0       0       0       0       0       0       0        1
# 148       0       0       0       1       0       0       0        0
# 94        0       0       1       0       0       0       0        0
# 88        1       0       0       0       0       0       0        0
#
# [167 rows x 8 columns]

# %% [markdown]
# Para columna RAD, se creo un Dummys tanto para Train como para Test, un Dummys permite convertir los valores contenidos en una columna en atributos y volverlos 0 y 1. (binarios), ademas con la funcion drop_first=True, evitamos la multicolinealidad, (correlacion entre columnas).

# %%
X_train_2=pd.concat([X_train_2, dum_train], axis=1)
X_train_2
# Out:
#           CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 357   0.992627  0.00  0.646628     1  0.792181  0.274457  0.907312 -0.213956
# 58   -0.030221  2.00  0.171188     0  0.139918 -0.065217  0.270855  1.422965
# 418  20.281332  0.00  0.646628     0  0.604938 -0.320652  1.000000 -0.430564
# 105  -0.036264  0.00  0.296921     0  0.277778 -0.464674  0.966014 -0.336750
# 487   1.265545  0.00  0.646628     0  0.407407 -0.391304  0.518023 -0.014459
# ..         ...   ...       ...   ...       ...       ...       ...       ...
# 421   1.870886  0.00  0.646628     0  0.685185 -0.254076  0.951596 -0.408367
# 215  -0.018161  0.00  0.371334     0  0.213992 -0.014946  0.406797  0.230049
# 298  -0.055075  5.60  0.065249     0  0.030864  0.206522  0.177137  1.426973
# 305  -0.057807  2.64  0.063050     0  0.179012  0.574728  0.568486  0.052657
# 331  -0.059069  2.80  0.205279     0  0.108848 -0.661685  0.262616  1.060996
#
# ...

# %%
X_test_2=pd.concat([X_test_2, dum_test], axis=1)
X_test_2
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 139  0.117975  0.00  0.779412     0  0.477801 -0.087393  0.977540 -0.531349
# 258  0.162433  1.60  0.103695     0  0.526427  1.606017  1.000000 -0.456489
# 390  2.515754  0.00  0.636501     0  0.638478 -0.714900  0.967914 -0.445917
# 290 -0.072386  6.40  0.140649     0  0.027484  0.929799  0.228877  0.611280
# 166  0.665584  0.00  0.692308     0  0.437632  2.459885  0.959358 -0.406349
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 389  2.960213  0.00  0.636501     0  0.638478 -1.177650  0.988235 -0.511665
# 393  3.144417  0.00  0.636501     0  0.623679 -0.027221  0.920856 -0.490754
# 148  0.785443  0.00  0.692308     0  1.000000 -1.469914  0.933690 -0.577446
# 94  -0.069427  2.24  0.521116     0  0.139535  0.053009  0.757219  0.113633
# 88  -0.064323  0.00  0.082579     0  0.192389  1.138968  0.853476  0.049576
#
# ...

# %% [markdown]
# Concatenamos Train + Dummis Train (67%) y Test + Dummis test (33%). con los datos ya transformados.

# %%
X_train_2=X_train_2.drop("RAD",axis=1)

# %%
X_train_2
# Out:
#           CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 357   0.992627  0.00  0.646628     1  0.792181  0.274457  0.907312 -0.213956
# 58   -0.030221  2.00  0.171188     0  0.139918 -0.065217  0.270855  1.422965
# 418  20.281332  0.00  0.646628     0  0.604938 -0.320652  1.000000 -0.430564
# 105  -0.036264  0.00  0.296921     0  0.277778 -0.464674  0.966014 -0.336750
# 487   1.265545  0.00  0.646628     0  0.407407 -0.391304  0.518023 -0.014459
# ..         ...   ...       ...   ...       ...       ...       ...       ...
# 421   1.870886  0.00  0.646628     0  0.685185 -0.254076  0.951596 -0.408367
# 215  -0.018161  0.00  0.371334     0  0.213992 -0.014946  0.406797  0.230049
# 298  -0.055075  5.60  0.065249     0  0.030864  0.206522  0.177137  1.426973
# 305  -0.057807  2.64  0.063050     0  0.179012  0.574728  0.568486  0.052657
# 331  -0.059069  2.80  0.205279     0  0.108848 -0.661685  0.262616  1.060996
#
# ...

# %%
X_test_2=X_test_2.drop("RAD",axis=1)
X_test_2
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 139  0.117975  0.00  0.779412     0  0.477801 -0.087393  0.977540 -0.531349
# 258  0.162433  1.60  0.103695     0  0.526427  1.606017  1.000000 -0.456489
# 390  2.515754  0.00  0.636501     0  0.638478 -0.714900  0.967914 -0.445917
# 290 -0.072386  6.40  0.140649     0  0.027484  0.929799  0.228877  0.611280
# 166  0.665584  0.00  0.692308     0  0.437632  2.459885  0.959358 -0.406349
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 389  2.960213  0.00  0.636501     0  0.638478 -1.177650  0.988235 -0.511665
# 393  3.144417  0.00  0.636501     0  0.623679 -0.027221  0.920856 -0.490754
# 148  0.785443  0.00  0.692308     0  1.000000 -1.469914  0.933690 -0.577446
# 94  -0.069427  2.24  0.521116     0  0.139535  0.053009  0.757219  0.113633
# 88  -0.064323  0.00  0.082579     0  0.192389  1.138968  0.853476  0.049576
#
# ...

# %% [markdown]
# #### Conclusiones para:  X_train_2 y X_test_2:
# 1- los conjuntos de datos quedaron, totalmente de tipo numerico, el Atributo CHAS Y RAD(1,2,3,4,5,6,7,8,24) son binarios. asi el conjunto de datos quedo homogeneizado y contenido en 339 filas y 21 columnas para X_Train_2 y 167 filas y 21 columnas para X_Test_2.
#
# 2- El Preprocesamiento de datos nos permite unificar y homogeneizar el tipo de datos para su posterior procesamiento. debemos tener en cuenta que cada atributo es independiente ( para este caso ) y por tanto sus datos pueden ser de cualquier tipo, y su procesamiento sera diferente. con el fin de que puedan ser procesados de forma correcta.
#
# 3- Para la estandarización (RobustScaler), los datos se escalaron en relacion a la mediana y al rango intercuartil, es normal que haya datos negativos.
#
# 4- Para la normalizacion (MinMaxScaler), los datos se ajustan en un rango comunmente de 0 a 1, y los datos se distribuyen en este rango.

# %% [markdown]
# ### Ejercicio 3
#
# Resume las nuevas columnas generadas de forma estadística y gráfica

# %% [markdown]
# #### Comparacion con Analisis estadistico inicial y X_train_2 y X_test_2:
#
# 1- Los rangos de los datos en el analisis estadistico inicial(506), son amplios y varian. Los rangos son  y en X_train_2 (339)y X_test_2 (167), los rangos son mas pequeños y se acercan al 0, centro 0.
#
# 2- los rangos de los datos en el analisis estadistico inicial son dispersos y no tienen un rango que los contenga. En X_train_2 y X_test_2, son menos dispersos y estan dentro del rango cuyo centro es 0.
#
# 3- La desviacion estandar, reduce los valores cercanos a cero en todas las variables. el Analisis estadisticos inicial los valores varian.

# %%
df.describe().round(3) #Analisis estadistico inicial
# Out:
#           CRIM       ZN    INDUS     CHAS      NOX       RM      AGE      DIS  \
# count  506.000  506.000  506.000  506.000  506.000  506.000  506.000  506.000
# mean     3.614   11.364   11.137    0.069    0.555    6.285   68.575    3.795
# std      8.602   23.322    6.860    0.254    0.116    0.703   28.149    2.106
# min      0.006    0.000    0.460    0.000    0.385    3.561    2.900    1.130
# 25%      0.082    0.000    5.190    0.000    0.449    5.885   45.025    2.100
# 50%      0.257    0.000    9.690    0.000    0.538    6.208   77.500    3.207
# 75%      3.677   12.500   18.100    0.000    0.624    6.624   94.075    5.188
# max     88.976  100.000   27.740    1.000    0.871    8.780  100.000   12.126
#
#            RAD      TAX  PTRATIO        B    LSTAT     MEDV
# count  506.000  506.000  506.000  506.000  506.000  506.000
# mean     9.549  408.237   18.456  356.674   12.653   22.533
# std      8.707  168.537    2.165   91.295    7.141    9.197
# ...

# %%
X_train_2.describe().round(3)
# Out:
#           CRIM       ZN    INDUS     CHAS      NOX       RM      AGE      DIS  \
# count  339.000  339.000  339.000  339.000  339.000  339.000  339.000  339.000
# mean     0.991    0.926    0.397    0.065    0.345    0.111    0.680    0.198
# std      2.641    1.886    0.249    0.247    0.229    0.987    0.292    0.677
# min     -0.070    0.000    0.000    0.000    0.000   -3.576    0.000   -0.638
# 25%     -0.050    0.000    0.190    0.000    0.132   -0.432    0.414   -0.339
# 50%      0.000    0.000    0.346    0.000    0.315    0.000    0.786    0.000
# 75%      0.950    1.000    0.647    0.000    0.492    0.568    0.942    0.661
# max     24.556    8.000    1.000    1.000    1.000    3.515    1.000    2.752
#
#            TAX  PTRATIO        B    LSTAT   RAD__2   RAD__3   RAD__4   RAD__5  \
# count  339.000  339.000  339.000  339.000  339.000  339.000  339.000  339.000
# mean     0.428   -0.217   -1.670    0.144    0.044    0.074    0.215    0.212
# ...

# %%
X_test_2.describe().round(3)
# Out:
#           CRIM       ZN    INDUS     CHAS      NOX       RM      AGE      DIS  \
# count  167.000  167.000  167.000  167.000  167.000  167.000  167.000  167.000
# mean     1.091    0.874    0.363    0.078    0.340    0.133    0.657    0.142
# std      2.344    1.829    0.265    0.269    0.264    0.936    0.298    0.635
# min     -0.083    0.000    0.000    0.000    0.000   -2.269    0.000   -0.638
# 25%     -0.055    0.000    0.130    0.000    0.107   -0.402    0.423   -0.391
# 50%      0.000    0.000    0.261    0.000    0.266    0.000    0.727    0.000
# 75%      0.945    1.000    0.637    0.000    0.485    0.598    0.925    0.609
# max     15.431    7.600    1.000    1.000    1.000    3.570    1.000    2.424
#
#            TAX  PTRATIO        B    LSTAT   RAD__2   RAD__3   RAD__4   RAD__5  \
# count  167.000  167.000  167.000  167.000  167.000  167.000  167.000  167.000
# mean     0.409   -0.213   -1.647    0.105    0.054    0.078    0.222    0.257
# ...

# %% [markdown]
# #### Resumen estadistico: X_train_2 y X_test_2:
#
# Las nuevas columnas:  son de clasificacion de tipo binaria, su rango es de 0 y 1, solo nos dice si este tipo de carretera radial esta cercana a cada zona.
#
# Las nuevas columnas generadas evitan la multicolinealidad, evitando que todas las columnas Rad tengan una correlacion entre si ( demostrado en el heatmap mas abajo).
#
# Mean: el promedio de los dos conjuntos es similar a pesar de que son muy diferentes es extension.
#
# Std: son similares en sus rangos de desviacion estandar.
#
# min: son similares excepto por las variables LSTAT, que hay diferencia pero esta dentro del mismo rango esta vez negativo
#
# Max: son similares excepto por las variables CRIM Y LSTAT.
#
# Vamos a comprobarlo graficamente.
#
# Graficamente tambien podemos confirmar que los dos conjuntos son similares en cuanto a promedio, desviacion estandar, minimos yt maximos, asi su cantidad sea diferente, la distribucion de los datos es similar.

# %% [markdown]
# #### HISTOGRAMAS

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(16, 10))
for i, column in enumerate(df.columns):
    plt.subplot(4, 4, i+1)
    sns.histplot(df[column], kde=True)
    plt.title(column)
plt.suptitle("Histogramas DF Inicial", y=1.02, fontsize=20)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(18, 15))
for i, column in enumerate(X_train_2.columns):
    plt.subplot(6, 4, i+1)
    sns.histplot(X_train_2[column], kde=True)
    plt.title(column)
plt.suptitle("Histogramas para X_train_2", y=1.02, fontsize=20)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(18, 15))
for i, column in enumerate(X_test_2.columns):
    plt.subplot(6, 4, i+1)
    sns.histplot(X_test_2[column], kde=True)
    plt.title(column)
plt.suptitle("Histogramas para X_test_2", y=1.02, fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# Comparación entre Histogramas:
# 1- Los rangos de los histogramas cambian antes y despues de la tranformación. En X_train_2 y X_test_2 los rangos son pequeños cuyo centro es 0.
#
# 2- Los histogramas son iguales, la forma de cada histograma antes y despues de la tranformacion de los datos, solo cambina los rangos en que se representan. pero cada variable sigue teniendo la misma forma.
#
# 3- La consistencia del a distribución y variabilidad (Homogenizacion) de los datos, es igual antes y despues de la tranformacion. significaria que a pesar de ser escalados, mantienen su estructura. es importante mantener la homogeneidad de los datos.

# %% [markdown]
# #### BOXPLOT

# %%
plt.figure(figsize=(16, 10))
sns.boxplot(data=df)
plt.title('Boxplots DF Inicial')
plt.show()

# %%
plt.figure(figsize=(16, 10))
sns.boxplot(data=X_train_2)
plt.title('Boxplots de X_train_2')
plt.show()

# %%
plt.figure(figsize=(16, 10))
sns.boxplot(data=X_test_2)
plt.title('Boxplots de X_test_2')
plt.show()

# %% [markdown]
# Comparación entre BOXPLOT:
#
# 1- Centro 0: Como se puede cobservar en los Boxplot, el centro de los datos variaba antes de la tranformacion entre variables. no tenian un mismo centro. luego de las transformaciones el centro es el 0 para todas las variables.
#
# 2- Rangos: los rangos de las variables antes, eran amplias y diferentes, dependiendo de la variable y lo que representaran. sin embargo luego de las transformaciones los rangos, disminuyeron su expensión, (0,1) para todas las variables, con una mediana cercana a cero.
#
# 3- Ouliers: las variables antes y despues, se presentan en las mismas variables. CRIM, ZN, CHAS, RM, DIS, TAX, B,LSTAT.

# %% [markdown]
# #### MATRICES DE CORRELACIÓN

# %%
correlation_matrix = X_train_2.corr()
sns.set(style="white")
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5)
plt.title("Matriz de Correlación X_train_2")
plt.show()

# %% [markdown]
# Las mayor correlaciones significan que la fuerza de ambas variables y direccion de la relacion lineal aumentan o disminuyen a la vez. entre mas cercana al 1, sea la correlación, mas fuerte es.
#
# CRIM: Indicaria que la criminalidad incluye en un 0.55 a los impuestos a la propiedad (TAX), positiva o negativamente, y con el indice de accesibilidad a carreteras radiales (RAD_24) un 0.60.
#
# ZN: la proporcion del suelo para uso residencial (ZN), depende un 0.70 de (DIS)la distancia a centros urbanos. se podria decir que entre mayor distancia a centros urbanos el uso del suelo aumenta para uso residencial.
#
# INDUS: Proporcion de acres para la industria por ciudad depende 0.78 La concentracion de acido nitrico (NOX) alta correlacion, si aumenta la concentracion, aumentara la proporcion de suelo para la industria , tambien se relaciona 0.66, con las unidades de vivienda contruidas por sus propietarios, antes de 1940 (AGE), a medida que aumentan estas unidades de vivienda aumentan los proporcion de acres para la industria(AGE), y aumentan ademas (TAX) 0.71, (LSTAT)0.59, y aumenta el indice de eccesibilidad (RAD_24)0.61
#
# CHAS: No tiene una gran correlacion con ninguna otra variable al ser binaria y de clasificacion.
#
# Conclusion: se observa que las variables CRIM, INDUS,NOX,AGE,TAX,LSTAT Y RAD_24, son las variables que mas se relacionan entre si.

# %%
correlation_matrix = X_test_2.corr()
sns.set(style="white")
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5)
plt.title("Matriz de Correlación X_test_2")
plt.show()

# %% [markdown]
# X_test_2:
# Las mayor correlaciones significan que la fuerza de ambas variables y direccion de la relacion lineal aumentan o disminuyen a la vez. entre mas cercana al 1, sea la correlación, mas fuerte es.
#
# CRIM: Indicaria que la criminalidad incluye en un 0.71 a los impuestos a la propiedad (TAX), positiva o negativamente, y con el indice de accesibilidad a carreteras radiales (RAD_24) un 0.78.
#
# ZN: la proporcion del suelo para uso residencial (ZN), depende un 0.59 de (DIS)la distancia a centros urbanos. se podria decir que entre mayor distancia a centros urbanos el uso del suelo aumenta para uso residencial.
#
# INDUS: Proporcion de acres para la industria por ciudad depende 0.75 La concentracion de acido nitrico (NOX) alta correlacion, si aumenta la concentracion, aumentara la proporcion de suelo para la industria, tambien se relaciona 0.61, con las unidades de vivienda contruidas por sus propietarios, antes de 1940 (AGE), a medida que aumentan estas unidades de vivienda aumentan los proporcion de acres para la industria(INDUS), ademas (TAX) 0.73, (LSTAT)0.63, y aumenta el indice de eccesibilidad (RAD_24)0.58
#
# CHAS: No tiene una gran correlacion con ninguna otra variable al ser binaria y de clasificacion.
#
# Conclusion: se observa que las variables CRIM, INDUS,NOX,AGE,TAX,LSTAT Y RAD_24, son las variables que mas se relacionan entre si.
#
#
# #### Conclusion de matriz para X_train y X_test_2:
#
# Al comparar: X_train y X_test_2, las matrices de correlacion, son similares, los rangos de correlacion entre variables varian, pero son minimos los cambios que se presentan. por tanto las correlaciones mas fuertes, entre variables en ambos conjuntos es similar.
#
# Nota: uso matriz de correlacion en este punto para  entender las relaciones entre las variables en los conjunto de datos preprocesados y luego e ser tranfomados.

# %% [markdown]
# #### para exportar conjuntos a tarea 6

# %%
df_train = pd.DataFrame(X_train_2, columns=["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "TAX", "PTRATIO", "B", "LSTAT", "RAD__2", "RAD__3", "RAD__4", "RAD__5", "RAD__6", "RAD__7", "RAD__8", "RAD__24"])
df_train['MEDV'] = y_train
df_test = pd.DataFrame(X_test_2, columns=["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "TAX", "PTRATIO", "B", "LSTAT", "RAD__2", "RAD__3", "RAD__4", "RAD__5", "RAD__6", "RAD__7", "RAD__8", "RAD__24"])
df_test['MEDV'] = y_test
df_train.to_csv('train_data.csv', index=False)
df_test.to_csv('test_data.csv', index=False)
